# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import pickle
from scipy.io import readsav

# %%
# import in the data

with open('PFISR_Conductance_20121106T0608UT_20121106T1459UTAFOSRYIP.pkl', 'r') as f:
    d = pickle.load(f)

# %%
dsdi = readsav('/Users/srkaeppler/research/data/pfisr/conductance_allsky/events/20121106/ISR/sav/02052015/20121106_All_q0100_e010_02092015.sav')

# %%
d.keys()
# Out:
# ['HallConductivity',
#  'UnixTime',
#  'PedersenConductivity',
#  'Ne',
#  'PedersenConductance',
#  'TimeUTHour',
#  'HallConductance']

# %%
dsdi['sh_arr_glo']
# Out:
# array([ 0.        ,  0.        ,  1.82995435,  1.90441816,  1.20068072,
#         1.30841328,  0.89221402,  0.60368699,  0.97721289,  0.77675019,
#         0.82905519,  1.40521334,  1.36292917,  1.04340402,  0.58703712,
#         0.92544953,  0.81506893,  0.92928464,  0.6979535 ,  1.14934163,
#         0.61784374,  0.89416719,  0.74498675,  0.78211358,  1.03120685,
#         1.10252272,  1.09779647,  1.43636486,  1.51041017,  1.60805664,
#         1.68829471,  2.3492721 ,  3.64032529,  4.50328037,  4.3177273 ,
#         3.55242574,  4.68993684,  3.86837185,  3.12117043,  3.65962992,
#         4.72011795,  6.31900505,  4.61018107,  5.16555371,  6.72710131,
#         6.29689418,  6.21972097,  4.82083875,  4.71845583,  4.04757547,
#         4.24385839,  5.18186542,  4.36227452,  4.74308896,  4.70649413,
#         4.76271548,  4.92783811,  4.6823496 ,  3.39398655,  3.98126436,
#         3.55417893,  3.28749491,  3.03617452,  3.54532809,  2.93553424,
#         2.56542506,  3.13097603,  2.52570958,  2.77374054,  3.52072111,
#         3.35732679,  5.25770563,  4.4549161 ,  4.98562223,  5.15473216,
#         5.72752974,  4.8848245 ,  5.4764989 ,  4.6043878 ,  4.27140439,
#         3.95544287,  3.96979305,  4.01191107,  4.83312717,  5.7546044 ,
#         5.55701602,  5.65980553,  5.65697088,  5.27783109,  6.08130498,
#         5.75716842,  7.16321953,  6.44980094,  4.32619082,  3.49959229,
#         3.4866607 ,  4.18219444,  2.95947302,  2.93249963,  2.49792007,
#         4.1363069 ,  3.43883314,  3.05757532,  3.49850889,  4.30808112,
#         4.96422298,  3.71329843,  3.46963406,  3.98835759,  3.18600182,
#         3.43518555,  4.09008966,  5.5899254 ,  6.90903352,  7.61059863,
#         8.75216489, 13.83095424, 17.62650043, 18.55101108, 15.90543559,
#        11.53301935, 12.21281053, 23.97317384, 32.85320949, 31.13345048,
#        27.11194618, 39.82592247, 42.53794731, 33.2658858 , 29.50135113,
#        26.29790144, 23.04273993, 20.77011112, 18.83398419, 16.92651126,
#        18.33323838, 18.73341715, 23.30696422, 26.77048042, 26.13049918,
#        31.28530921, 43.90100308, 40.54821429, 32.50194795, 31.38662575,
#        27.73991886, 31.89592378, 30.77687471, 26.99669906, 23.31599766,
#        24.31038609, 20.04944575, 20.9533944 , 23.69232866, 25.68854853,
#        27.14597806, 28.28375759, 26.31932495, 26.1222721 , 30.84917577,
#        29.77449044, 30.05061825, 28.78333504, 37.09145487, 33.38244388,
#        33.60473563, 28.07289415, 26.85918114, 26.80737334, 24.13768665,
#        23.89396227])

# %%
plt.figure(dpi=300, figsize=(11,8.5))
plt.plot(dsdi['time_arr_glo'],dsdi['sh_arr_glo'][2:],'r-', label='2015Results')
plt.plot(d['TimeUTHour'],d['HallConductance'], 'b-', label='FastConduct')
plt.legend(loc=2)

# %%
plt.figure(dpi=300, figsize=(11,8.5))
plt.plot(dsdi['time_arr_glo'],dsdi['sp_arr_glo'][2:],'r-', label='2015Results')
plt.plot(d['TimeUTHour'],d['PedersenConductance'], 'b-', label='FastConduct')
plt.legend(loc=2)
